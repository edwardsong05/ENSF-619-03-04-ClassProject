# %%
import json
from nltk.tokenize import RegexpTokenizer
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re
import string

# %% [markdown]
# # process the tweets
# open the tweets, process them, then save them back into the json format

# %%
# open files to read and write from
in_filename = 'SampleData.json'
out_filename = 'prepared_json.json'

in_handle = open(in_filename, encoding='utf8')
out_handle = open(out_filename, 'w', encoding='utf8')

# %%
# process the tweet and adds in negation terms
# adds a not to every word after a token of logical negation
# until the next puncutation mark

puncuation = {'"', ',', '.', '?', '!'}

# adapted from https://stackoverflow.com/questions/23384351/how-to-add-tags-to-negated-words-in-strings-that-follow-not-no-and-never
def check_and_negate(tweet: str):
    tweet = tweet.strip()
    # check if the end of the tweet has a puncuation mark and add if not
    if len(tweet) > 0 and tweet[-1] not in puncuation:
        tweet += '.'
    tweet = re.sub('n\'t', ' not', tweet) # replace n't with not
    tweet = re.sub('n’t', ' not', tweet)
    # add NOT_ to the beginning of each word until a end of sentence mark (.,!?) occurs
    tweet = re.sub(r'\b(?:not|never|no)\b[\'\w\s]+[.,?!"]', 
                   lambda match: re.sub(r'(\s+)(\w+)', r'\1NOT_\2', match.group(0)), 
                   tweet,
                   flags=re.IGNORECASE)
    return tweet

# %%
# remove stop words
stop_words = set(stopwords.words('english'))

tokenizer = RegexpTokenizer(r'\w+') # remove punctuation and keep only words
ps = PorterStemmer()

def remove_stop_and_stem(tweet: str):
    words = []
    tokens = tokenizer.tokenize(tweet)
    for token in tokens:
        if token not in stop_words:
            words.append(ps.stem(token))
    return ' '.join(words)

# %%
# processes the tweet
# https://towardsdatascience.com/the-real-world-as-seen-on-twitter-sentiment-analysis-part-one-5ac2d06b63fb
def process_tweet(tweet: str):
    tweet = tweet.lower() # convert to lowercase
    tweet = re.sub(r'#\w*', '', tweet) # remove hashtags
    tweet = re.sub('@\S+', '', tweet) # remove @username
    tweet = re.sub('\s+', ' ', tweet) # remove multiple whitespace
    # https://stackoverflow.com/questions/6038061/regular-expression-to-find-urls-within-a-string
    tweet = re.sub('(http|ftp|https)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?', '', tweet) # remove links
    tweet = check_and_negate(tweet)# add negations
    tweet = remove_stop_and_stem(tweet) # remove stop words and stem
    tweet.strip() # remove excess leading and trailing whitespace
    return tweet

# %%
j_items = []

for line in in_handle:
    # convert json object into python dict, append to list
    item = json.loads(line)
    j_items.append(item)
    # perform cleaning and preparation
    if 'text' in item: # check that the dictionary contains the key
        print('before:', item['text'])
        item['text'] = process_tweet(item['text']) # convert to lowercase
        print('after:', item['text'])
    # write the json object into an output file
    out_handle.write(json.dumps(item))
    out_handle.write('\n')
# Out:
# today show well miracl made sinc car block ice wo not_start tune se
# well top great team goal sadio
# mi siempr morena de cardedeu
# remedi intellig staf hire ny click link bio appli packag
# pleas leav organ harvest profession
# know feel
#
# encantaria tener su servicio señor
# bra att arbrtsf
# not_you not_sash not_m
# eu na festa surpresa meu irmão ano passado e ele na minha kkk
# così da 5 anni ora basta
# all definitiv all nur jung und schlank
# go
# nice except fact shot 15 ft per game
# hippodrom est risqué
# やばいよね 外人ばっか
# hi niet een line al zul je wel degelijk mensen hiervan horen gewoon een ordinair reclametweet
# sdd meu migo e da gent fofocando
# super rayado
# قزرت كورنرات
# 8th grade gator visit weiss energi hall welch hall chemistri houston museum natur scienc
# pleasur contribut idea latest articl effect way promot
# yeah came home sit chair twitter
# feldbergfight
# true
# şüphesiz allah ında bir hesabı var
# tudo bem
# thank silken mean lot come one hero
# mayb tri sound bath help detail
# call attent
# mamo kkkkkkkkkkkkkkkkkk
# brolarla sezonuna hazırlığımız sezonun ilk maçı ekip ateş ediyor 2015 2016 sezonu
# lmaooo nah
# not_sé not_si not_m not_gusta
# recién leo un md que dejó helada nunca quis ofend nadi ni que lo tomarán como person algo que escrib
# not_veo not_la not_hora not_d not_irm not_a not_la not_mierrda
# bill came 666 let god pay one
# baysid marina miami fl
# baru saja mengirim foto ponp sholchah
# food staff incred super attent awesom atmospher servic plu f
# still not_mean not_a not_coupl not_of not_punk not_who not_did not_it not_could not_not not_hav not_said not_that not_stuff not_just not_to not_impl
# al ver la foto solo puedo pemsar par de hijueputa
# two hour alreadi score twizzler fun size skittl best trade show ever
# türk ün yurdu
# pued ser cierto esto en mi méxico querido
# ط
# poi formata logo ai que quero aprend
# aaaaaaaand wear sneaker fantast
# se le premess sono quest contro l atletico ci credo zero ci inculano con la sabbia
#
#
# да после того вопроса я вспомнила про этот пиздатый сериал и решила пересмотреть только этот сериал во
# ver si saben
# ya va not_m not_queda not_claro not_como not_s not_llama not_di not_martino not_o not_tri not_mardito
# vamo atuzina ess churra ai
# eso sin duda
# origin plan post beauti queen side today howev could ignor pow
# start comprehend unpopular opinion mean
# es lo que opinamo tode
# hoje foi segunda vez que peguei not_volant not_ not_eu not_simplesment not_morro not_do not_coração
#
# est ce qu une équip féminin peut tenir longtemp san clash disput
#
# eu só queria uma polarzinha bem gelada aff
# globo visión dio noticia están de diciendo lo mosca
# 2 day appli make differ commun meet likemind young peopl want creat c
# oootiiiiii amp bu tiiiiiii
# dirilişimiz bu güzel günde daim olsun
# palestinian die gaza isra sniper fire via
#
# esto va ser muy complicado para mí corazón
# أي حنا أتفقنا أنا فاهمين بعض بس مو هالهدرجه والله هالإنسان بيجنني أنت شلون عرفت أنه في
# karın harika görünüyor
# vamo véi é pertinho kkkk de boa
# ta um calor caceta
# saco meu pai
# celular dele tá sem hora kkk
# tell lot person groceri cart
# love mait sit also love l antagonist chez oskar tri hehe
# promot ava max si
# pinta arremangado amigo extraña
# hey im not_a not_fat not_a not_i not_wa
# hainlerin yanlış hesabı
# q vontad comer agr mano
# yhooi kunzima
# sizler sağolun mert inşallah kardeşim çok teşekkürl
# want em
# greater elect fraud necessari democrat 2020 ballot harvest begin
# non la démocrati en march en faisant cela il protèg le manifest et le polici
# rip momma dawn windchil 40 lol fuckkkkk
# thank fjp cci lay prosecutor lead cj reform
# buy 4x4 u got plenti money
# знакомство с родителями обмен посольствами
# até na praia tem foto pé e shop even
# yodah aku mo wamil dulu kabari kalau udah oke yaa
# sempr assim cunhada
# buena noch chico hoy le traigo un nuevo video podéi verlo completo en nuestro canal princip
# شعور صعب اوي بجد بتخاف بعدها تاخد اي قرار او تمشي في اي طريق لان بيكون مسيطر عليك فكره واحده ان ممكن الطريق دا يكون
# everi tweet retweet today hashtag 5 cent donat mental health initit
# questo si è visto un film
# wahhh
# bahçelievl belediy başkan adayımız dr hakan bahadır aracılığıyla
# googl tell cognito stop support googl
# yessssssssssssssss
# bird feather flock togeth kontinu
# wow tax return yesterday alreadi account
# davamız yalnızca allah ın davasıdır
# saw uh basebal team practic today thought spring train almost
# está peor amigo
# detallazo de gent que se despid que dejarán huella para siempr mucha gracia cri
# none
#
# mental health not_follow not_a not_linear not_lin sign depress anxieti stress not_alway not_obvi
# need tell meathead stick right amp get mist und
# lmao red last man
# 8½
# need
#
# metido en la feria pero solament por necesidad
# headach
# woke 20 di bitch
# sim ainda mai aquel não eu nao tenho isso de padrão gosto da pessoa que fazem bem
# julio would domin corner era say deion sander would heck matchup
# dia de sorriso genuíno sorriso da alma sorriso de amor em jijoca de jericoacoara
# yeah compon qualiti still atroci
# você tá bem
# ndiko toda uvhona vhutolo matshelo uri naa zwido konadzea naa
# voce è muito meu amor
#
# lol probabl
# ok pasam el dato pli tengo un par de amiga que lo aprovecharán
# hermosa
# sturdi bridg fine
# gündüz ü çok seviyoruz
# hahahahaha
# cuando lo tipo má cuentan meno hacen
#
# thick head idiot democrat ca not_se not_b not_on not_your not_nos not_blam not_trump not_and not_republican

# %%
in_handle.close()
print('input file closed')
out_handle.close()
print('output file closed')
# Out:
# input file closed
# output file closed

# %%
# Print out a tweet with formatting
print(json.dumps(j_items[1], indent=4))
# Out:
# {
#     "created_at": "Wed Jan 30 20:42:09 +0000 2019",
#     "id": 1090711786720874500,
#     "id_str": "1090711786720874496",
#     "text": "",
#     "display_text_range": [
#         25,
#         25
#     ],
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "truncated": false,
#     "in_reply_to_status_id": 1090711475998515200,
#     "in_reply_to_status_id_str": "1090711475998515201",
#     "in_reply_to_user_id": 4894106887,
#     "in_reply_to_user_id_str": "4894106887",
#     "in_reply_to_screen_name": "yaminivalli_01",
#     "user": {
#         "id": 297542334,
#         "id_str": "297542334",
#         "name": "\u0430\u0434\u0438\u0442\u0439\u0430",
#         "screen_name": "Backstreet_Boy3",
#         "location": "Madras",
#         "url": "https://www.facebook.com/SuperstarPrinceMaheshBabuGhattamaneni",
#         "description": "Hated by many, wanted by plenty, disliked by some, confronted by none! \ud83c\udfc7",
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 704,
#         "friends_count": 304,
#         "listed_count": 6,
#         "favourites_count": 2126,
#         "statuses_count": 36952,
#         "created_at": "Thu May 12 17:46:50 +0000 2011",
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": true,
#         "lang": "en",
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "76B32E",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": true,
#         "profile_link_color": "76B32E",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "E1E288",
#         "profile_text_color": "146F86",
#         "profile_use_background_image": true,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/969525886046257155/QfBcR3gH_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/969525886046257155/QfBcR3gH_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/297542334/1503205151",
#         "default_profile": false,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": {
#         "id": "2f749857a5d4a129",
#         "url": "https://api.twitter.com/1.1/geo/id/2f749857a5d4a129.json",
#         "place_type": "city",
#         "name": "Dibrugarh",
#         "full_name": "Dibrugarh, India",
#         "country_code": "IN",
#         "country": "India",
#         "bounding_box": {
#             "type": "Polygon",
#             "coordinates": [
#                 [
#                     [
#                         94.570608,
#                         27.093794
#                     ],
#                     [
#                         94.570608,
#                         27.707991
#                     ],
#                     [
#                         95.49144,
#                         27.707991
#                     ],
#                     [
#                         95.49144,
#                         27.093794
#                     ]
#                 ]
#             ]
#         },
#         "attributes": {}
#     },
#     "contributors": null,
#     "is_quote_status": false,
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "favorite_count": 0,
#     "entities": {
#         "hashtags": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "screen_name": "yaminivalli_01",
#                 "name": "Yamini hasini",
#                 "id": 4894106887,
#                 "id_str": "4894106887",
#                 "indices": [
#                     0,
#                     15
#                 ]
#             },
#             {
#                 "screen_name": "arrahman",
#                 "name": "A.R.Rahman",
#                 "id": 19895282,
#                 "id_str": "19895282",
#                 "indices": [
#                     16,
#                     25
#                 ]
#             }
#         ],
#         "symbols": [],
#         "media": [
#             {
#                 "id": 1090711766588215300,
#                 "id_str": "1090711766588215296",
#                 "indices": [
#                     26,
#                     49
#                 ],
#                 "media_url": "http://pbs.twimg.com/tweet_video_thumb/DyL8kqfUUAA3NT6.jpg",
#                 "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DyL8kqfUUAA3NT6.jpg",
#                 "url": "https://t.co/SPuWgKsWsL",
#                 "display_url": "pic.twitter.com/SPuWgKsWsL",
#                 "expanded_url": "https://twitter.com/Backstreet_Boy3/status/1090711786720874496/photo/1",
#                 "type": "photo",
#                 "sizes": {
#                     "large": {
#                         "w": 88,
#                         "h": 90,
#                         "resize": "fit"
#                     },
#                     "small": {
#                         "w": 88,
#                         "h": 90,
#                         "resize": "fit"
#                     },
#                     "medium": {
#                         "w": 88,
#                         "h": 90,
#                         "resize": "fit"
#                     },
#                     "thumb": {
#                         "w": 88,
#                         "h": 88,
#                         "resize": "crop"
#                     }
#                 }
#             }
#         ]
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "id": 1090711766588215300,
#                 "id_str": "1090711766588215296",
#                 "indices": [
#                     26,
#                     49
#                 ],
#                 "media_url": "http://pbs.twimg.com/tweet_video_thumb/DyL8kqfUUAA3NT6.jpg",
#                 "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DyL8kqfUUAA3NT6.jpg",
#                 "url": "https://t.co/SPuWgKsWsL",
#                 "display_url": "pic.twitter.com/SPuWgKsWsL",
#                 "expanded_url": "https://twitter.com/Backstreet_Boy3/status/1090711786720874496/photo/1",
#                 "type": "animated_gif",
#                 "video_info": {
#                     "aspect_ratio": [
#                         44,
#                         45
#                     ],
#                     "variants": [
#                         {
#                             "bitrate": 0,
#                             "content_type": "video/mp4",
#                             "url": "https://video.twimg.com/tweet_video/DyL8kqfUUAA3NT6.mp4"
#                         }
#                     ]
#                 },
#                 "sizes": {
#                     "large": {
#                         "w": 88,
#                         "h": 90,
#                         "resize": "fit"
#                     },
#                     "small": {
#                         "w": 88,
#                         "h": 90,
#                         "resize": "fit"
#                     },
#                     "medium": {
#                         "w": 88,
#                         "h": 90,
#                         "resize": "fit"
#                     },
#                     "thumb": {
#                         "w": 88,
#                         "h": 88,
#                         "resize": "crop"
#                     }
#                 }
#             }
#         ]
#     },
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": false,
#     "filter_level": "low",
#     "lang": "und",
#     "timestamp_ms": "1548880929056"
# }

# %%
print(json.dumps(j_items[2], indent=4))
# Out:
# {
#     "created_at": "Wed Jan 30 20:42:08 +0000 2019",
#     "id": 1090711785651474400,
#     "id_str": "1090711785651474432",
#     "text": "today show well miracl made sinc car block ice wo not_start tune se",
#     "display_text_range": [
#         0,
#         140
#     ],
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "truncated": true,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#         "id": 237010321,
#         "id_str": "237010321",
#         "name": "Andy Jorgensen",
#         "screen_name": "StuckWithAndy",
#         "location": "Milton, WI",
#         "url": "https://www.facebook.com/repjorgensen",
#         "description": "Former democratic leader in the Wisconsin State Assembly, now has his own radio show Stuck In The Middle with Andy Jorgensen on 940am WFAW from 3-5pm!",
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 2302,
#         "friends_count": 1841,
#         "listed_count": 83,
#         "favourites_count": 364,
#         "statuses_count": 5051,
#         "created_at": "Tue Jan 11 21:45:11 +0000 2011",
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": true,
#         "lang": "en",
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/466995640929484800/XqJS0VKA_normal.jpeg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/466995640929484800/XqJS0VKA_normal.jpeg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/237010321/1400175512",
#         "default_profile": true,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": {
#         "id": "7dc5c6d3bfb10ccc",
#         "url": "https://api.twitter.com/1.1/geo/id/7dc5c6d3bfb10ccc.json",
#         "place_type": "admin",
#         "name": "Wisconsin",
#         "full_name": "Wisconsin, USA",
#         "country_code": "US",
#         "country": "United States",
#         "bounding_box": {
#             "type": "Polygon",
#             "coordinates": [
#                 [
#                     [
#                         -92.889433,
#                         42.491921
#                     ],
#                     [
#                         -92.889433,
#                         47.309715
#                     ],
#                     [
#                         -86.24955,
#                         47.309715
#                     ],
#                     [
#                         -86.24955,
#                         42.491921
#                     ]
#                 ]
#             ]
#         },
#         "attributes": {}
#     },
#     "contributors": null,
#     "is_quote_status": false,
#     "extended_tweet": {
#         "full_text": "On today's show...well it's a miracle I made it, since my car is now a block of ice and won't start. Tune in and see what surprises I'll have. I'll be surprised too!\nStuck in the Middle with Andy Jorgensen weekdays from 3-5pm on https://t.co/PmShRZCxCN https://t.co/1WOj18t85X",
#         "display_text_range": [
#             0,
#             252
#         ],
#         "entities": {
#             "hashtags": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/PmShRZCxCN",
#                     "expanded_url": "http://940wfaw.com",
#                     "display_url": "940wfaw.com",
#                     "indices": [
#                         229,
#                         252
#                     ]
#                 }
#             ],
#             "user_mentions": [],
#             "symbols": [],
#             "media": [
#                 {
#                     "id": 1090711774670639100,
#                     "id_str": "1090711774670639104",
#                     "indices": [
#                         253,
#                         276
#                     ],
#                     "media_url": "http://pbs.twimg.com/tweet_video_thumb/DyL8lImUUAArQX0.jpg",
#                     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DyL8lImUUAArQX0.jpg",
#                     "url": "https://t.co/1WOj18t85X",
#                     "display_url": "pic.twitter.com/1WOj18t85X",
#                     "expanded_url": "https://twitter.com/StuckWithAndy/status/1090711785651474432/photo/1",
#                     "type": "animated_gif",
#                     "video_info": {
#                         "aspect_ratio": [
#                             83,
#                             42
#                         ],
#                         "variants": [
#                             {
#                                 "bitrate": 0,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/tweet_video/DyL8lImUUAArQX0.mp4"
#                             }
#                         ]
#                     },
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 498,
#                             "h": 252,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 498,
#                             "h": 252,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 498,
#                             "h": 252,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1090711774670639100,
#                     "id_str": "1090711774670639104",
#                     "indices": [
#                         253,
#                         276
#                     ],
#                     "media_url": "http://pbs.twimg.com/tweet_video_thumb/DyL8lImUUAArQX0.jpg",
#                     "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/DyL8lImUUAArQX0.jpg",
#                     "url": "https://t.co/1WOj18t85X",
#                     "display_url": "pic.twitter.com/1WOj18t85X",
#                     "expanded_url": "https://twitter.com/StuckWithAndy/status/1090711785651474432/photo/1",
#                     "type": "animated_gif",
#                     "video_info": {
#                         "aspect_ratio": [
#                             83,
#                             42
#                         ],
#                         "variants": [
#                             {
#                                 "bitrate": 0,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/tweet_video/DyL8lImUUAArQX0.mp4"
#                             }
#                         ]
#                     },
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 498,
#                             "h": 252,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 498,
#                             "h": 252,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 498,
#                             "h": 252,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         }
#     },
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "favorite_count": 0,
#     "entities": {
#         "hashtags": [],
#         "urls": [
#             {
#                 "url": "https://t.co/SKa1JA0OIZ",
#                 "expanded_url": "https://twitter.com/i/web/status/1090711785651474432",
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "indices": [
#                     117,
#                     140
#                 ]
#             }
#         ],
#         "user_mentions": [],
#         "symbols": []
#     },
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": false,
#     "filter_level": "low",
#     "lang": "en",
#     "timestamp_ms": "1548880928801"
# }

# %%
# test the negation
test = "really? sure hope this isn’t right because it just wrong. good grief. respectfully submitted."
print(process_tweet(test))
# Out:
# realli sure hope not_right not_becaus not_it not_just not_wrong good grief respect submit
